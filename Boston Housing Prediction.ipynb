# %% [markdown]
# #                          *Boston Housing Price Prediction*

# %% [markdown]
# ![r1.jpg](attachment:r1.jpg)

# %%
import pandas as pd 
import matplotlib.pyplot as plot
import numpy as np
import seaborn as sns 

# %matplotlib inline

#data

# %%
data = pd.read_csv('Boston1.csv')

# %%
data.shape
# Out:
# (506, 14)

# %%
data.head(2)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
#
#    black  lstat  medv
# 0  396.9   4.98  24.0
# 1  396.9   9.14  21.6

# %%
data.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
data_ = data.loc[:,['lstat','medv']]
# lstat is Percentage of lower status of the population
data_.head(5)
# Out:
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# # Visualizing variables

# %%
import matplotlib.pyplot as plt

data.plot(x='lstat',y='medv',style='o') #style = list or dict
    # The matplotlib line style per column.
plt.xlabel('lstat')
plt.ylabel('medv')
plt.show()

# %% [markdown]
# # Preparing data

# %%
X = pd.DataFrame(data['lstat'])
y = pd.DataFrame(data['medv'])

# %%
X
# Out:
#      lstat
# 0     4.98
# 1     9.14
# 2     4.03
# 3     2.94
# 4     5.33
# ..     ...
# 501   9.67
# 502   9.08
# 503   5.64
# 504   6.48
# 505   7.88
#
# [506 rows x 1 columns]

# %%
y
# Out:
#      medv
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
X.size, y.size
# Out:
# (506, 506)

# %% [markdown]
# Splitting The Data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 1)
# (102, 1)
# (404, 1)
# (102, 1)

# %% [markdown]
# # Training

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression() 
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.coef_)
print(regressor.fit_intercept)
# Out:
# [[-0.92441715]]
# True

# %%
y_pred = regressor.predict(X_test)
y_pred = pd.DataFrame(y_pred, columns=['Predicted'])

# %%
y_pred.head(5)
# Out:
#    Predicted
# 0  27.374117
# 1  27.697663
# 2  16.955936
# 3  26.847199
# 4  24.915168

# %% [markdown]
# the actual values of predictions are given below:medv

# %%
y_test.head(5)
# Out:
#      medv
# 307  28.2
# 343  23.9
# 47   16.6
# 67   22.0
# 362  20.8

# %% [markdown]
# # R Square- Coefficient of Determination, Goodness of Fit - metrics

# %% [markdown]
# Test data

# %%
 from sklearn.metrics import r2_score
ac_sl=r2_score(y_test, y_pred, sample_weight=None)
ac_sl
# Out:
# 0.5244757432765152

# %%
y_pred = regressor.predict(X_test)
y_pred = pd.DataFrame(y_pred, columns=['Predicted'])

# %% [markdown]
# # Accuracy for our Training Data

# %%
y_TrainPred = regressor.predict(X_train)
y_TrainPred = pd.DataFrame(y_TrainPred, columns=['TrainPredicted'])

# %%
y_TrainPred
# Out:
#      TrainPredicted
# 0         28.964115
# 1         27.993477
# 2          5.853686
# 3         22.927671
# 4         18.471980
# ..              ...
# 399       25.784120
# 400       29.232196
# 401       16.429018
# 402       24.277320
# 403       26.227840
#
# [404 rows x 1 columns]

# %%
r2_score(y_train, y_TrainPred, sample_weight=None)
# Out:
# 0.5495280791456811

# %% [markdown]
# # Mulitple Linear Regression

# %%
import pandas as pd
import numpy as np
dataset = pd.read_csv('Boston1.csv')
#dataset

# %%
dataset.head(5)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# 2) Multiple Linear Regression with many  variables

# %%
X = pd.DataFrame(dataset.iloc[:,:-1])
y = pd.DataFrame(dataset.iloc[:,-1])

# %%
X
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
y
# Out:
#      medv
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 1)
# (102, 1)
# (404, 1)
# (102, 1)

# %%
X_test.head(5)
# Out:
#      lstat
# 307   7.53
# 343   7.18
# 47   18.80
# 67    8.10
# 362  10.19

# %%
X.head(5)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
regressor = LinearRegression()
regressor.fit(X_train,  y_train)
# Out:
# LinearRegression()

# %%
print(regressor.coef_) #Slope = m
print(regressor.intercept_)#intercept = c
# Out:
# [[-0.92441715]]
# [34.33497839]

# %%
X_test.head(5)
# Out:
#      lstat
# 307   7.53
# 343   7.18
# 47   18.80
# 67    8.10
# 362  10.19

# %%
y_pred = regressor.predict(X_test)
y_pred = pd.DataFrame(y_pred, columns=['Predicted'])
y_pred.head(5)
# Out:
#    Predicted
# 0  27.374117
# 1  27.697663
# 2  16.955936
# 3  26.847199
# 4  24.915168

# %%
y_test.head(5)
# Out:
#      medv
# 307  28.2
# 343  23.9
# 47   16.6
# 67   22.0
# 362  20.8

# %%
from sklearn import metrics  
from sklearn.metrics import r2_score
ac_ml=r2_score(y_test, y_pred, sample_weight=None)

ac_ml
# Out:
# 0.5244757432765152

# %%
print(X_test)
# Out:
#      lstat
# 307   7.53
# 343   7.18
# 47   18.80
# 67    8.10
# 362  10.19
# ..     ...
# 92    8.16
# 224   4.14
# 110  13.00
# 426  15.69
# 443  18.85
#
# [102 rows x 1 columns]

# %%
df1 = pd.DataFrame(y_test) 
df2 = pd.DataFrame(y_pred)

# %%
type(df1.medv)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
df1.merge(df2, left_on='medv', right_index=True).reset_index()
# Out:
# C:\Users\ANC\lib\site-packages\pandas\core\reshape\merge.py:1205: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   warnings.warn(
#     index  medv  Predicted
# 0      67  22.0  25.756387
# 1     285  22.0  25.756387
# 2     132  23.0  28.677545
# 3     326  23.0  28.677545
# 4     225  50.0  23.556274
# 5     204  50.0  23.556274
# 6     162  50.0  23.556274
# 7     370  50.0  23.556274
# 8     257  50.0  23.556274
# 9     324  25.0  11.788444
# 10    165  25.0  11.788444
# 11     29  21.0  18.943433
# 12    128  18.0  27.466559
# 13    449  13.0  24.868947

# %% [markdown]
# # Exploratory Data Analysis for improve the Model Accuracy

# %%
correlation_matrix = data.corr().round(2)

# %%
correlation_matrix
# Out:
#          crim    zn  indus  chas   nox    rm   age   dis   rad   tax  ptratio  \
# crim     1.00 -0.20   0.41 -0.06  0.42 -0.22  0.35 -0.38  0.63  0.58     0.29
# zn      -0.20  1.00  -0.53 -0.04 -0.52  0.31 -0.57  0.66 -0.31 -0.31    -0.39
# indus    0.41 -0.53   1.00  0.06  0.76 -0.39  0.64 -0.71  0.60  0.72     0.38
# chas    -0.06 -0.04   0.06  1.00  0.09  0.09  0.09 -0.10 -0.01 -0.04    -0.12
# nox      0.42 -0.52   0.76  0.09  1.00 -0.30  0.73 -0.77  0.61  0.67     0.19
# rm      -0.22  0.31  -0.39  0.09 -0.30  1.00 -0.24  0.21 -0.21 -0.29    -0.36
# age      0.35 -0.57   0.64  0.09  0.73 -0.24  1.00 -0.75  0.46  0.51     0.26
# dis     -0.38  0.66  -0.71 -0.10 -0.77  0.21 -0.75  1.00 -0.49 -0.53    -0.23
# rad      0.63 -0.31   0.60 -0.01  0.61 -0.21  0.46 -0.49  1.00  0.91     0.46
# tax      0.58 -0.31   0.72 -0.04  0.67 -0.29  0.51 -0.53  0.91  1.00     0.46
# ptratio  0.29 -0.39   0.38 -0.12  0.19 -0.36  0.26 -0.23  0.46  0.46     1.00
# black   -0.39  0.18  -0.36  0.05 -0.38  0.13 -0.27  0.29 -0.44 -0.44    -0.18
# lstat    0.46 -0.41   0.60 -0.05  0.59 -0.61  0.60 -0.50  0.49  0.54     0.37
# medv    -0.39  0.36  -0.48  0.18 -0.43  0.70 -0.38  0.25 -0.38 -0.47    -0.51
#
#          black  lstat  medv
# crim     -0.39   0.46 -0.39
# zn        0.18  -0.41  0.36
# indus    -0.36   0.60 -0.48
# chas      0.05  -0.05  0.18
# nox      -0.38   0.59 -0.43
# rm        0.13  -0.61  0.70
# age      -0.27   0.60 -0.38
# dis       0.29  -0.50  0.25
# rad      -0.44   0.49 -0.38
# tax      -0.44   0.54 -0.47
# ptratio  -0.18   0.37 -0.51
# black     1.00  -0.37  0.33
# lstat    -0.37   1.00 -0.74
# medv      0.33  -0.74  1.00

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
#multicolinearity between rad and tax, so drop rad
#multicolinearity between distance and age, so drop age

bdata = pd.DataFrame(data)

bdata = bdata.drop(columns=['rad'])
#bdata = bdata.drop(columns=['tax'])
bdata = bdata.drop(columns=['age'])

bfeatures=bdata.drop(columns=['medv'])
bfeatures=bdata.drop(columns=['medv'])

X = pd.DataFrame(bfeatures)
y = pd.DataFrame(bdata['medv'])

# %%
y
# Out:
#      medv
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
X
# Out:
#         crim    zn  indus  chas    nox     rm     dis  tax  ptratio   black  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  4.0900  296     15.3  396.90
# 1    0.02731   0.0   7.07     0  0.469  6.421  4.9671  242     17.8  396.90
# 2    0.02729   0.0   7.07     0  0.469  7.185  4.9671  242     17.8  392.83
# 3    0.03237   0.0   2.18     0  0.458  6.998  6.0622  222     18.7  394.63
# 4    0.06905   0.0   2.18     0  0.458  7.147  6.0622  222     18.7  396.90
# ..       ...   ...    ...   ...    ...    ...     ...  ...      ...     ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  2.4786  273     21.0  391.99
# 502  0.04527   0.0  11.93     0  0.573  6.120  2.2875  273     21.0  396.90
# 503  0.06076   0.0  11.93     0  0.573  6.976  2.1675  273     21.0  396.90
# 504  0.10959   0.0  11.93     0  0.573  6.794  2.3889  273     21.0  393.45
# 505  0.04741   0.0  11.93     0  0.573  6.030  2.5050  273     21.0  396.90
#
#      lstat
# 0     4.98
# 1     9.14
# 2     4.03
# 3     2.94
# 4     5.33
# ..     ...
# 501   9.67
# 502   9.08
# 503   5.64
# 504   6.48
# 505   7.88
#
# [506 rows x 11 columns]

# %%
bdata.head(5)
# Out:
#       crim    zn  indus  chas    nox     rm     dis  tax  ptratio   black  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  4.0900  296     15.3  396.90
# 1  0.02731   0.0   7.07     0  0.469  6.421  4.9671  242     17.8  396.90
# 2  0.02729   0.0   7.07     0  0.469  7.185  4.9671  242     17.8  392.83
# 3  0.03237   0.0   2.18     0  0.458  6.998  6.0622  222     18.7  394.63
# 4  0.06905   0.0   2.18     0  0.458  7.147  6.0622  222     18.7  396.90
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# Again we are training the data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
regressor = LinearRegression()
regressor.fit(X_train,  y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred = pd.DataFrame(y_pred, columns=['Predicted'])
y_pred.head(5)
# Out:
#    Predicted
# 0  36.997638
# 1  31.196728
# 2  27.891660
# 3   4.595376
# 4  35.211412

# %%
from sklearn import metrics  
from sklearn.metrics import r2_score
ac_ml_no_rad=r2_score(y_test, y_pred, sample_weight=None)
ac_ml_no_rad
# Out:
# 0.7386215922474408

# %% [markdown]
# # detecting outliers

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

sns.distplot(data['medv'], bins=30)
plt.show()
# Out:
# C:\Users\ANC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
for i in dataset.columns:
    sns.boxplot(dataset[i])
    plt.show()
# Out:
# C:\Users\ANC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ANC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ANC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ANC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ANC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ANC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ANC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ANC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ANC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ANC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ANC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ANC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ANC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ANC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# pairplot
sns.pairplot(data)
plt.savefig("pairplot.png")
plt.clf()
plt.close()

# %%
sns.scatterplot(dataset['rad'], dataset['medv'])
#sns.scatterplot(dataset['indus'], dataset['tax'])
plt.show()
# Out:
# C:\Users\ANC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # remove outliers

# %% [markdown]
# ### using z-score to remove ouliter

# %%
from scipy import stats

# %%
dataset.head(4)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4

# %%
# calculate z score
z = np.abs(stats.zscore(dataset))

print(z)
z.shape
# Out:
#          crim        zn     indus      chas       nox        rm       age  \
# 0    0.419782  0.284830  1.287909  0.272599  0.144217  0.413672  0.120013
# 1    0.417339  0.487722  0.593381  0.272599  0.740262  0.194274  0.367166
# 2    0.417342  0.487722  0.593381  0.272599  0.740262  1.282714  0.265812
# 3    0.416750  0.487722  1.306878  0.272599  0.835284  1.016303  0.809889
# 4    0.412482  0.487722  1.306878  0.272599  0.835284  1.228577  0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501  0.413229  0.487722  0.115738  0.272599  0.158124  0.439316  0.018673
# 502  0.415249  0.487722  0.115738  0.272599  0.158124  0.234548  0.288933
# 503  0.413447  0.487722  0.115738  0.272599  0.158124  0.984960  0.797449
# 504  0.407764  0.487722  0.115738  0.272599  0.158124  0.725672  0.736996
# 505  0.415000  0.487722  0.115738  0.272599  0.158124  0.362767  0.434732
#
#           dis       rad       tax   ptratio     black     lstat      medv
# 0    0.140214  0.982843  0.666608  1.459000  0.441052  1.075562  0.159686
# 1    0.557160  0.867883  0.987329  0.303094  0.441052  0.492439  0.101524
# 2    0.557160  0.867883  0.987329  0.303094  0.396427  1.208727  1.324247
# 3    1.077737  0.752922  1.106115  0.113032  0.416163  1.361517  1.182758
# 4    1.077737  0.752922  1.106115  0.113032  0.441052  1.026501  1.487503
# ..        ...       ...       ...       ...       ...       ...       ...
# 501  0.625796  0.982843  0.803212  1.176466  0.387217  0.418147  0.014454
# 502  0.716639  0.982843  0.803212  1.176466  0.441052  0.500850  0.210362
# 503  0.773684  0.982843  0.803212  1.176466  0.441052  0.983048  0.148802
# 504  0.668437  0.982843  0.803212  1.176466  0.403225  0.865302  0.057989
# 505  0.613246  0.982843  0.803212  1.176466  0.441052  0.669058  1.157248
#
# [506 rows x 14 columns]
# (506, 14)

# %%
# any data point with z-score greater then 3 is an outlier
threshold = 3
print(np.where(z>3))
# Out:
# (array([ 55,  56,  57, 102, 141, 142, 152, 154, 155, 160, 162, 163, 199,
#        200, 201, 202, 203, 204, 208, 209, 210, 211, 212, 216, 218, 219,
#        220, 221, 222, 225, 234, 236, 256, 257, 262, 269, 273, 274, 276,
#        277, 282, 283, 283, 284, 347, 351, 352, 353, 353, 354, 355, 356,
#        357, 358, 363, 364, 364, 365, 367, 369, 370, 372, 373, 374, 374,
#        380, 398, 404, 405, 406, 410, 410, 411, 412, 412, 414, 414, 415,
#        416, 418, 418, 419, 423, 424, 425, 426, 427, 427, 429, 431, 436,
#        437, 438, 445, 450, 454, 455, 456, 457, 466], dtype=int64), array([ 1,  1,  1, 11, 12,  3,  3,  3,  3,  3,  3,  3,  1,  1,  1,  1,  1,
#         1,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  3,  5,  3,  3,  1,  5,
#         5,  3,  3,  3,  3,  3,  3,  1,  3,  1,  1,  7,  7,  1,  7,  7,  7,
#         3,  3,  3,  3,  3,  5,  5,  5,  3,  3,  3, 12,  5, 12,  0,  0,  0,
#         0,  5,  0, 11, 11, 11, 12,  0, 12, 11, 11,  0, 11, 11, 11, 11, 11,
#        11,  0, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11],
#       dtype=int64))

# %%
new_df = dataset[(z <=3.3).all(axis=1)]

# %%
dataset.shape, new_df.shape
# Out:
# ((506, 14), (431, 14))

# %% [markdown]
# Again we are training the data

# %%
X = pd.DataFrame(new_df.iloc[:,:-1])
y = pd.DataFrame(new_df.iloc[:,-1])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
regressor3 = LinearRegression()
regressor3.fit(X_train,  y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor3.predict(X_test)
y_pred = pd.DataFrame(y_pred, columns=['Predicted'])
y_pred.head(5)
# Out:
#    Predicted
# 0  19.441466
# 1  21.519113
# 2  13.654576
# 3  20.964062
# 4  36.607263

# %%
from sklearn import metrics  
from sklearn.metrics import r2_score
ac_ml_no_out=r2_score(y_test, y_pred, sample_weight=None)
ac_ml_no_out
# Out:
# 0.7357349503601995

# %% [markdown]
# # IQR Score

# %%
q1 = dataset.quantile(0.25)
q3 = dataset.quantile(0.75)
IQR = q3 - q1

print(IQR)
# Out:
# crim         3.595038
# zn          12.500000
# indus       12.910000
# chas         0.000000
# nox          0.175000
# rm           0.738000
# age         49.050000
# dis          3.088250
# rad         20.000000
# tax        387.000000
# ptratio      2.800000
# black       20.847500
# lstat       10.005000
# medv         7.975000
# dtype: float64

# %%
iqr_outlier = (dataset <  (q1 - 1.5 * IQR)) | (dataset > (q3 + 1.5 * IQR))

print(iqr_outlier)
# Out:
#       crim     zn  indus   chas    nox     rm    age    dis    rad    tax  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 501  False  False  False  False  False  False  False  False  False  False
# 502  False  False  False  False  False  False  False  False  False  False
# 503  False  False  False  False  False  False  False  False  False  False
# 504  False  False  False  False  False  False  False  False  False  False
# 505  False  False  False  False  False  False  False  False  False  False
#
#      ptratio  black  lstat   medv
# 0      False  False  False  False
# 1      False  False  False  False
# 2      False  False  False  False
# 3      False  False  False  False
# 4      False  False  False  False
# ..       ...    ...    ...    ...
# 501    False  False  False  False
# 502    False  False  False  False
# 503    False  False  False  False
# 504    False  False  False  False
# 505    False  False  False  False
#
# [506 rows x 14 columns]

# %% [markdown]
# # Remove outliers (IQR score)

# %%
new_df_iq = dataset[~((dataset < (q1 - 1.5 * IQR)) | (dataset > (q3 + 1.5 * IQR))).any(axis=1)]

# %%
new_df_iq.shape
# Out:
# (268, 14)

# %%
X = pd.DataFrame(new_df_iq.iloc[:,:-1])
y = pd.DataFrame(new_df_iq.iloc[:,-1])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
# Creating a LinearRegression object and fitting it
# on our trainging set.
regressor4 = LinearRegression()
#fit means CREATE AND EQUATION , CREATE MODEL, TRAIN THE MODEL

#linear
#X_train, X_test, y_train, y_test
regressor4.fit(X_train,  y_train)
#y = .1x + 3.3
# Out:
# LinearRegression()

# %%
y_pred = regressor4.predict(X_test)
y_pred = pd.DataFrame(y_pred, columns=['Predicted'])
y_pred.head(5)
# Out:
#    Predicted
# 0  20.819778
# 1  25.663841
# 2  15.258809
# 3  21.168544
# 4  22.373896

# %%
from sklearn import metrics  
from sklearn.metrics import r2_score
ac_ml_no_iqr=r2_score(y_test, y_pred, sample_weight=None)
ac_ml_no_iqr
# Out:
# 0.6068371235053756

# %%
acc_data= {'simple linear regression' :  [ac_sl],
       'multilinear regression': [ac_ml],
       'drop rad' : [ac_ml_no_rad],
       'remove_outliers with z-score' : [ac_ml_no_out],
        'remove_iqr' : [ac_ml_no_iqr]  
          }

# %%
models=['Accuracy']

# %%
Result=pd.DataFrame(acc_data, index= models)
Result
# Out:
#           simple linear regression  multilinear regression  drop rad  \
# Accuracy                  0.524476                0.524476  0.738622
#
#           remove_outliers with z-score  remove_iqr
# Accuracy                      0.735735    0.606837

# %% [markdown]
# # Using 3 Columns

# %%
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data4 = data.loc[:,['rm','ptratio','lstat','tax','medv']]
data4.head(5)
# Out:
#       rm  ptratio  lstat  tax  medv
# 0  6.575     15.3   4.98  296  24.0
# 1  6.421     17.8   9.14  242  21.6
# 2  7.185     17.8   4.03  242  34.7
# 3  6.998     18.7   2.94  222  33.4
# 4  7.147     18.7   5.33  222  36.2

# %%
X = pd.DataFrame(data4.iloc[:,:-1])
y = pd.DataFrame(data4.iloc[:,-1])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
regressor5 = LinearRegression()
regressor5.fit(X_train,  y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor5.predict(X_test)
y_pred = pd.DataFrame(y_pred, columns=['Predicted'])
y_pred.head(5)
# Out:
#    Predicted
# 0  36.546163
# 1  28.327684
# 2  26.161494
# 3   1.115746
# 4  31.875326

# %%
from sklearn import metrics  
from sklearn.metrics import r2_score
ac_ml_data4=r2_score(y_test, y_pred, sample_weight=None)
ac_ml_data4
# Out:
# 0.6936559148531667

# %% [markdown]
# # Standerd Scaler

# %%
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
data4d=data
data4d.head(5)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
X = pd.DataFrame(data4d.iloc[:,:-1])
y = pd.DataFrame(data4d.iloc[:,-1])

# %%
X.shape
# Out:
# (506, 13)

# %%
y.shape
# Out:
# (506, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train= sc.fit_transform(X_train)
X_test= sc.transform(X_test)

# %%
regressor6 = LinearRegression()
regressor6.fit(X_train,  y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor6.predict(X_test)
y_pred = pd.DataFrame(y_pred, columns=['Predicted'])
y_pred.head(5)
# Out:
#    Predicted
# 0  37.563118
# 1  32.144451
# 2  27.065736
# 3   5.670806
# 4  35.099826

# %%
from sklearn import metrics  
from sklearn.metrics import r2_score
ac_ml_sc=r2_score(y_test, y_pred, sample_weight=None)
ac_ml_sc
# Out:
# 0.7334492147453073

# %% [markdown]
# # Decsion Tree- Random Forest Regressor

# %% [markdown]
# it will output or predict continous numbers.
# it is difference from the Decsion Tree Classifier that outputs or predicts categorical values

# %%
X = pd.DataFrame(data.iloc[:,:-1])
y = pd.DataFrame(data.iloc[:,-1])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
# Import Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor

# Create a Random Forest Regressor
regRFG = RandomForestRegressor()

# Train the model using the training sets 
regRFG.fit(X_train, y_train)
# Out:
# C:\Users\vinit\AppData\Local\Temp/ipykernel_11244/2323836254.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regRFG.fit(X_train, y_train)
# RandomForestRegressor()

# %%
y_pred = regRFG.predict(X_test)
y_pred = pd.DataFrame(y_pred, columns=['Predicted'])
y_pred.head(5)
# Out:
#    Predicted
# 0     46.314
# 1     28.036
# 2     22.608
# 3     11.657
# 4     41.249

# %%
from sklearn import metrics  
from sklearn.metrics import r2_score
ac_ml_regRFG=r2_score(y_test, y_pred, sample_weight=None)
ac_ml_regRFG
# Out:
# 0.8702163838610144

# %% [markdown]
# Here we got Good accuracy with 87%, So our model is performing Good.
